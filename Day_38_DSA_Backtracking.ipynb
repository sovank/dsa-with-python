# %% [markdown]
# <a href="https://colab.research.google.com/github/sovank/dsa-with-python/blob/main/Day_38_DSA_Backtracking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def generate_subsets(arr, current_subset, index, all_subsets):

    # Base condition
    if index == len(arr):
        all_subsets.append(current_subset.copy())
        return

    # Pick
    current_subset.append(arr[index])
    generate_subsets(arr, current_subset, index + 1, all_subsets)

    # No-Pick ---> Exclude the current element (backtrack)
    current_subset.pop()
    generate_subsets(arr, current_subset, index + 1, all_subsets)

# Initialize variables
input_list = [1, 2, 3]
result = []

# Generate subsets
generate_subsets(input_list, [], 0, result)

# Print the result
print(result)
# Out:
# [[1, 2, 3], [1, 2], [1, 3], [1], [2, 3], [2], [3], []]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# __________________________________________________________________________________________________________

# %% [markdown]
# ![image.png](data:image/png;base64,...)
