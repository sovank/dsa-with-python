# %% [markdown]
# <a href="https://colab.research.google.com/github/Phanindra2009/dsa-with-python/blob/main/Day_45_DSA_Hashing_1_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Q1. Frequency of element query**
#
# Problem Description:
#
# Given an array A. You have some integers given in the array B.
# For the i-th number, find the frequency of B[i] in the array A and return a list containing all the frequencies.
#
#
# Problem Constraints:
#
# ## 1 <= |A| <= 10^5
# ## 1 <= |B| <= 10^5
# ## 1 <= A[i] <= 10^5
# ## 1 <= B[i] <= 10^5
#
#
# Input Format:
#
# First argument A is an array of integers.
# Second argument B is an array of integers denoting the queries.
#
#
# Output Format:
#
# Print an array of integers containing frequency of the each element in B.
#
#
# Example Input:
#
# Input 1:
#
# A = [1, 2, 1, 1]
#
# B = [1, 2]
#
# Input 2:
#
# A = [2, 5, 9, 2, 8]
#
# B = [3, 2]
#
#
# Example Output:
#
# Output 1:
#
# [3, 1]
#
# Output 2:
#
# [0, 2]
#
#
# Example Explanation:
#
# For Input 1:
#
# The frequency of 1 in the array A is 3.
#
# The frequency of 2 in the array A is 1.
#
# For Input 2:
#
# The frequency of 3 in the array A is 0.
#
# The frequency of 2 in the array A is 2.

# %%
A = list(map(int,input().split()))
B = list(map(int,input().split()))
freq_of_A_ele = {}
ans = []
for i in A:
    if i in freq_of_A_ele:
        freq_of_A_ele[i] += 1
    else:
        freq_of_A_ele[i] = 1
for i in B:
    if i in freq_of_A_ele:
        ans.append(freq_of_A_ele.get(i))
    else:
        ans.append(0)
print(ans)

# %% [markdown]
# # **Q2. Count distinct elements**
#
# Problem Description:
#
# Given an array A of N integers, return the number of unique elements in the array.
#
#
# Problem Constraints:\
#
# ## 1 <= N <= 105
#
# ## 1 <= A[i] <= 109
#
#
# Input Format:
#
# First argument A is an array of integers.
#
#
# Output Format:
#
# Print an integer.
#
#
# Example Input:
#
# Input 1:
#
# A = [3, 4, 3, 6, 6]
#
# Input 2:
#
# A = [3, 3, 3, 9, 0, 1, 0]
#
#
# Example Output:
#
# Output 1:
#
# 3
#
# Output 2:
#
# 4
#
#
# Example Explanation:
#
# For Input 1:
#
# The distinct elements of the array are 3, 4 and 6.
#
# For Input 2:
#
# The distinct elements of the array are 3, 9, 0 and 1.

# %%
A = list(map(int,input().split()))
A = set(A)
print(len(A))

# %% [markdown]
# ## **Q3. First Repeating element**
#
# Problem Description:
#
# Given an integer array A of size N, find the first repeating element in it.
#
# We need to find the element that occurs more than once and whose index of the first occurrence is the smallest.
#
# If there is no repeating element, return -1.
#
#
#
# Problem Constraints:
#
# ## 1 <= N <= 105
#
# ## 1 <= A[i] <= 109
#
#
#
# Input Format:
#
# The first and only argument is an integer array A of size N.
#
#
#
# Output Format:
#
# Print an integer denoting the first repeating element.
#
#
#
# Example Input:
#
# Input 1:
#
#  A = [10, 5, 3, 4, 3, 5, 6]
#
# Input 2:
#
#  A = [6, 10, 5, 4, 9, 120]
#
#
# Example Output:
#
# Output 1:
#
#  5
#
# Output 2:
#
#  -1
#
#
# Example Explanation:
#
# Explanation 1:
#
#  5 is the first element that repeats
#
# Explanation 2:
#
#  There is no repeating element, output -1

# %%
from re import I
A = list(map(int,input().split()))
freq_A = {}
for i in A:
    if i in freq_A:
        freq_A[i]  += 1
    else:
        freq_A[i] = 1
ans = -1
for i in A:
    if freq_A[i] > 1:
        ans = i
        break
print(ans)

# %% [markdown]
# ## **Q3. First Repeating element(More Optimized)**
#
# Problem Description:
#
# Given an integer array A of size N, find the first repeating element in it.
#
# We need to find the element that occurs more than once and whose index of the first occurrence is the smallest.
#
# If there is no repeating element, return -1.
#
#
#
# Problem Constraints:
# ## 1 <= N <= 10^5
#
# ## 1 <= A[i] <= 10^9
#
#
#
# Input Format:
#
# The first and only argument is an integer array A of size N.
#
#
#
# Output Format:
#
# Print an integer denoting the first repeating element.
#
#
#
# Example Input:
#
# Input 1:
#
#  A = [10, 5, 3, 4, 3, 5, 6]
#
# Input 2:
#
#  A = [6, 10, 5, 4, 9, 120]
#
#
# Example Output:
#
# Output 1:
#
#  5
#
# Output 2:
#
#  -1
#
#
# Example Explanation:
#
# Explanation 1:
#
#  5 is the first element that repeats
#
# Explanation 2:
#
#  There is no repeating element, output -1

# %%
A = list(map(int,input().split()))
N = len(A)
# initiating the index of repeating element
ind = -1
# Hashmap for checking repetative elements
check_dict = {}
for i in range(N-1,-1,-1):
    # checking the ele is repetative or not
    if check_dict.get(A[i]) != None:
        ind = i #updating the index
    else:
        check_dict[A[i]] = 1

if ind == -1:
    print(ind)
print(A[ind])

# %% [markdown]
# ## **Q4. Sub-array with 0 sum**
#
# Problem Description:
#
# Given an array of integers A, find and return whether the given array contains a non-empty subarray with a sum equal to 0.
#
# If the given array contains a sub-array with sum zero return 1, else return 0.
#
#
#
# Problem Constraints:
#
# ## 1 <= |A| <= 100000
#
# ## -10^9 <= A[i] <= 10^9
#
#
#
# Input Format:
#
# The only argument given is the integer array A.
#
#
#
# Output Format:
#
# Print whether the given array contains a subarray with a sum equal to 0.
#
#
#
# Example Input:
#
# Input 1:
#
#  A = [1, 2, 3, 4, 5]
#
# Input 2:
#
#  A = [4, -1, 1]
#
#
# Example Output:
#
# Output 1:
#
#  0
#
# Output 2:
#
#  1
#
#
# Example Explanation:
#
# Explanation 1:
#
#  No subarray has sum 0.
#
# Explanation 2:
#
#  The subarray [-1, 1] has sum 0.

# %%
A = list(map(int,input().split()))
N = len(A)
pfsum = [0] * (N+1)
for  i in range(N):
    pfsum[i] = pfsum[i-1] + A[i]
pfsum_freq = {}
ans = 0
for i in range(N+1):
    if pfsum[i] in pfsum_freq:
        ans = 1
        break
    else:
        pfsum_freq[pfsum[i]] = 1
print(ans)

# %% [markdown]
# ## **Q5. Count unique elements**
#
# Problem Description:
#
# You are given an array A of N integers. Return the count of elements with frequncy 1 in the given array.
#
#
# Problem Constraints:
#
# ## 1 <= N <= 105
#
# ## 1 <= A[i] <= 109
#
#
# Input Format:
#
# First argument A is an array of integers.
#
#
# Output Format:
#
# Print an integer.
#
#
# Example Input:
#
# Input 1:
#
# A = [3, 4, 3, 6, 6]
#
# Input 2:
#
# A = [3, 3, 3, 9, 0, 1, 0]
#
#
# Example Output:
#
# Output 1:
#
# 1
#
# Output 2:
#
# 2
#
#
# Example Explanation:
#
# Explanation 1:
#
# Only the element 4 has a frequency 1.
#
# Explanation 2:
#
# The elements 9 and 1 has a frequncy 1.

# %%
A = list(map(int,input().split()))
cnt = 0
A_dict = {}
for i in A:
    if i in A_dict:
        A_dict[i] += 1
    else:
        A_dict[i] = 1
for i in A_dict:
    if A_dict[i] == 1:
        cnt += 1
print(cnt)

# %% [markdown]
# ## **Q6. Count Subarray Zero Sum**
#
# Problem Description:
#
# Given an array A of N integers.
#
# Find the count of the subarrays in the array which sums to zero. Since the answer can be very large, return the remainder on dividing the result with 109+7
#
#
# Problem Constraints:
#
# ## 1 <= N <= 10^5
#
# ## -10^9 <= A[i] <= 10^9
#
#
# Input Format:
#
# Single argument which is an integer array A.
#
#
# Output Format:
#
# Return an integer.
#
#
# Example Input:
#
# Input 1:
#
#  A = [1, -1, -2, 2]
#
# Input 2:
#
#  A = [-1, 2, -1]
#
#
# Example Output:
#
# Output 1:
#
# 3
#
# Output 2:
#
# 1
#
#
# Example Explanation:
#
# Explanation 1:
#
#  The subarrays with zero sum are [1, -1], [-2, 2] and [1, -1, -2, 2].
#
# Explanation 2:
#
#  The subarray with zero sum is [-1, 2, -1].

# %%
A = list(map(int,input().split()))
N = len(A)
pfsum = [0] * (N+1)
for i in range(N):
    pfsum[i] = pfsum[i-1] + A[i]
cnt = 0
pfsum_frq = {}
for i in pfsum:
    if i in pfsum_frq:
        cnt += pfsum_frq[i]
        pfsum_frq[i] += 1
    else:
        pfsum_frq[i] = 1
print(cnt)

# %% [markdown]
# ## **Q7. Common Elements**
#
# Problem Description:
#
# Given two integer arrays, A and B of size N and M, respectively. Your task is to find all the common elements in both the array.
#
# NOTE:
#
# Each element in the result should appear as many times as it appears in both arrays.
# The result can be in any order.
#
#
# Problem Constraints:
#
# ## 1 <= N, M <= 10^5
#
# ## 1 <= A[i] <= 10^9
#
#
#
# Input Format:
#
# First argument is an integer array A of size N.
#
# Second argument is an integer array B of size M.
#
#
#
# Output Format:
#
# Return an integer array denoting the common elements.
#
#
#
# Example Input:
#
# Input 1:
#
#  A = [1, 2, 2, 1]
#
#  B = [2, 3, 1, 2]
#
# Input 2:
#
#  A = [2, 1, 4, 10]
#
#  B = [3, 6, 2, 10, 10]
#
#
# Example Output:
#
# Output 1:
#
#  [1, 2, 2]
#
# Output 2:
#
#  [2, 10]
#
#
# Example Explanation:
#
# Explanation 1:
#
#  Elements (1, 2, 2) appears in both the array. Note 2 appears twice in both the array.
#
# Explantion 2:
#
#  Elements (2, 10) appears in both the array.

# %%
A = list(map(int,input().split()))
B = list(map(int,input().split()))
A_freq = {}
for i in A:
    if i in A_freq:
        A_freq[i] += 1
    else:
        A_freq[i] = 1
ans = []
for i in B:
    if A_freq.get(i) != None and A_freq[i] != 0:
        ans.append(i)
        A_freq[i] -= 1
print(ans)
