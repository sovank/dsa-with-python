# %% [markdown]
# <a href="https://colab.research.google.com/github/Phanindra2009/dsa-with-python/blob/main/Day_33_DSA_Bit_Manipulation_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Q1. Unset i-th bit
# Problem Description:
#
# You are given two integers A and B.
#
# *   If B-th bit in A is set, make it unset.
# *   If B-th bit in A is unset, leave as it is.
#
#
# Print the updated A value.
#
# Note:
# The bit position is 0-indexed, which means that the least significant bit (LSB) has index 0.
#
#
# Problem Constraints:
#
# 1 <= A <= 10^9
#
# 0 <= B <= 30
#
#
# Input Format:
#
# A is an integer.
#
# B is an integer.
#
#
# Output Format:
#
# Return an integer.
#
#
# Example Input:
#
# Input 1:
#
# A = 4
#
# B = 1
#
# Input 2:
#
# A = 5
#
# B = 2
#
#
# Example Output:
#
# Output 1:
#
# 4
#
# Output 2:
#
# 1
#
#
# Example Explanation:
#
# For Input 1:
#
# Given N = 4 which is 100 in binary. The 1-st bit is already unset
#
# For Input 2:
#
# Given N = 5 which is 101 in binary. We unset the 2-nd bit
# It becomes 001 which is 1 in Decimal.

# %%
A = int(input())
B = int(input())
if A & (1<<(B)):
    print(A^(1<<(B)))
else:
    print(A)

# %% [markdown]
# # Q2. Check bit
# Problem Description:
#
# You are given two integers A and B.
# Print 1 if B-th bit in A is set
# Print 0 if B-th bit in A is unset
#
# Note:
#
# The bit position is 0-indexed, which means that the least significant bit (LSB) has index 0.
#
#
# Problem Constraints:
#
# # 1 <= A <= 10^9
#
# # 0 <= B <= 30
#
#
# Input Format:
#
# First input A is an integer.
#
# Second input B is an integer.
#
#
# Output Format:
#
# Print an integer.
#
#
# Example Input:
#
# Input 1:
#
# A = 4
#
# B = 1
#
# Input 2:
#
# A = 5
#
# B = 2
#
#
# Example Output:
#
# Output 1:
#
# 0
#
# Output 2:
#
# 1
#
#
# Example Explanation:
#
# For Input 1:
#
# Given N = 4 which is 100 in binary. The 1-st bit is unset
# so we print 0
#
# For Input 2:
#
# Given N = 5 which is 101 in binary. The 2-nd bit is set
# so we print 1

# %%
A = int(input())
B = int(input())
if A & (1<<B):
    print(1)
else:
    print(0)

# %% [markdown]
# # Q3. Number of 1 Bits
# Problem Description:
#
# Write a function that takes an integer and returns the number of 1 bits present in its binary representation.
#
#
# Problem Constraints:
#
# # 1 <= A <= 10^9
#
#
# Input Format:
# First and only input contains integer A
#
#
# Output Format:
#
# Print an integer
#
#
# Example Input:
#
# Input 1:
#
# 11
#
# Input 2:
#
# 6
#
#
# Example Output:
#
# Output 1:
#
# 3
#
# Output 2:
#
# 2
#
#
# Example Explanation:
#
# Explaination 1:
#
# 11 is represented as 1011 in binary.
#
# Explaination 2:
#
# 6 is represented as 110 in binary.

# %%
A = int(input())
count = 0
while A > 0:
    if A&1 == 1:
        count += 1
    A = A>>1
print(count)
